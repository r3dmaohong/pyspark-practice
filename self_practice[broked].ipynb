# %%
import random
num_samples = 100000000
def inside(p):     
  x, y = random.random(), random.random()
  return x*x + y*y < 1
count = sc.parallelize(range(0, num_samples)).filter(inside).count()
pi = 4 * count / num_samples
print(pi)
sc.stop()
# Out:
# 3.14200512

# %%
sc.master
# Out:
# 'local[*]'

# %%
conf = SparkConf().setAppName("app1").setMaster("local")
sc = SparkContext(conf=conf)

# %%
logFile = "file:///usr/local/Cellar/apache-spark/2.2.0/README.md"
logData = sc.textFile(logFile, 2).cache()
numAs = logData.filter(lambda line: 'a' in line).count()
numBs = logData.filter(lambda line: 'b' in line).count()
print('[Spark result] : Lines with a: %s, Lines with b: %s' % (numAs, numBs))
# Out:
# [Spark result] : Lines with a: 61, Lines with b: 30

# %%
textFile = sc.textFile("hdfs://localhost:9000/user/r3dmaohong/README.md")

# %%
textFile.count()
# Out:
# 103

# %%
import os
os.getcwd()
# Out:
# '/Users/r3dmaohong/workspace/dataScience/python/spark-projects/pyspark_with_jupyter'

# %%
dat = sc.textFile("file://" + os.getcwd() + "/opendata_test.csv")

# %%
dat.count()
# Out:
# 12

# %%
dat.first()
# Out:
# '年度別,融資調度需求,歲入歲出差短,債務還本,融資調度財源,賒借收入,移用以前年度歲計賸餘,自有財源比率,賦稅依存度,補助及協助依存度,債務未償餘額,債務未償餘額占歲出比例'

# %%
textFile.map(lambda r: Row(r)).toDF(["line"])
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /usr/local/Cellar/apache-spark/2.2.0/libexec/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /usr/local/Cellar/apache-spark/2.2.0/libexec/python/lib/py4j-0.10.4-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#
# Py4JJavaError: An error occurred while calling o213.applySchemaToPythonRDD.
# : java.lang.IllegalArgumentException: Error while instantiating 'org.apache.spark.sql.hive.HiveSessionStateBuilder':
# ...

# %%
from pyspark.sql import SQLContext, Row

# %%
# instantiate SQLContext object
sqlContext = SQLContext(sc)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /usr/local/Cellar/apache-spark/2.2.0/libexec/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /usr/local/Cellar/apache-spark/2.2.0/libexec/python/lib/py4j-0.10.4-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#
# Py4JJavaError: An error occurred while calling o213.sessionState.
# : java.lang.IllegalArgumentException: Error while instantiating 'org.apache.spark.sql.hive.HiveSessionStateBuilder':
# ...
